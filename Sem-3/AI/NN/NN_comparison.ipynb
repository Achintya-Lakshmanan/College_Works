# %% [markdown]
# <a href="https://colab.research.google.com/github/AchintyaSNU/AI_NN/blob/main/NN_comparison.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from nnfs.datasets import spiral_data


class Layer_Dense:

    def __init__(self, n_inputs, n_neurons):
        self.weights = 0.01 * np.random.randn(n_inputs, n_neurons)
        self.biases = np.zeros((1, n_neurons))

    def forward(self, inputs):
        self.inputs = inputs
        self.output = np.dot(inputs, self.weights) + self.biases

    def backward(self, dvalues):
        self.dweights = np.dot(self.inputs.T, dvalues)
        self.dbiases = np.sum(dvalues, axis=0, keepdims=True)
        self.dinputs = np.dot(dvalues, self.weights.T)

class Activation_ReLU:
    def forward(self, inputs):
        self.inputs = inputs
        self.output = np.maximum(0, inputs)

    def backward(self, dvalues):
        self.dinputs = dvalues.copy()
        self.dinputs[self.inputs <= 0] = 0

class Activation_Softmax:
    def forward(self, inputs):
        self.inputs = inputs
        exp_values = np.exp(inputs - np.max(inputs, axis=1, keepdims=True))
        probabilities = exp_values / np.sum(exp_values, axis=1, keepdims=True)

        self.output = probabilities

    def backward(self, dvalues):

        self.dinputs = np.empty_like(dvalues)

        for index, (single_output, single_dvalues) in \
                enumerate(zip(self.output, dvalues)):
            # Flatten output array
            single_output = single_output.reshape(-1, 1)
            # Calculate Jacobian matrix of the output
            jacobian_matrix = np.diagflat(single_output) - \
                              np.dot(single_output, single_output.T)

            # Calculate sample-wise gradient
            # and add it to the array of sample gradients
            self.dinputs[index] = np.dot(jacobian_matrix, single_dvalues)


class Loss:

    def calculate(self, output, y):
        sample_losses = self.forward(output, y)
        data_loss = np.mean(sample_losses)

        return data_loss

# Cross-entropy loss
class Loss_CategoricalCrossentropy(Loss):

    # Forward pass
    def forward(self, y_pred, y_true):

        # Number of samples in a batch
        samples = len(y_pred)

        # Clip data to prevent division by 0
        # Clip both sides to not drag mean towards any value
        y_pred_clipped = np.clip(y_pred, 1e-7, 1 - 1e-7)

        # Probabilities for target values -
        # only if categorical labels
        if len(y_true.shape) == 1:
            correct_confidences = y_pred_clipped[
                range(samples),
                y_true
            ]


        # Mask values - only for one-hot encoded labels
        elif len(y_true.shape) == 2:
            correct_confidences = np.sum(
                y_pred_clipped * y_true,
                axis=1
            )

        # Losses
        negative_log_likelihoods = -np.log(correct_confidences)
        return negative_log_likelihoods

    # Backward pass
    def backward(self, dvalues, y_true):

        # Number of samples
        samples = len(dvalues)
        # Number of labels in every sample
        # We'll use the first sample to count them
        labels = len(dvalues[0])

        # If labels are sparse, turn them into one-hot vector
        if len(y_true.shape) == 1:
            y_true = np.eye(labels)[y_true]

        # Calculate gradient
        self.dinputs = -y_true / dvalues
        # Normalize gradient
        self.dinputs = self.dinputs / samples


# Softmax classifier - combined Softmax activation
# and cross-entropy loss for faster backward step
class Activation_Softmax_Loss_CategoricalCrossentropy():

    # Creates activation and loss function objects
    def __init__(self):
        self.activation = Activation_Softmax()
        self.loss = Loss_CategoricalCrossentropy()

    # Forward pass
    def forward(self, inputs, y_true):
        # Output layer's activation function
        self.activation.forward(inputs)
        # Set the output
        self.output = self.activation.output
        # Calculate and return loss value
        return self.loss.calculate(self.output, y_true)


    # Backward pass
    def backward(self, dvalues, y_true):

        # Number of samples
        samples = len(dvalues)

        # If labels are one-hot encoded,
        # turn them into discrete values
        if len(y_true.shape) == 2:
            y_true = np.argmax(y_true, axis=1)

        # Copy so we can safely modify
        self.dinputs = dvalues.copy()
        # Calculate gradient
        self.dinputs[range(samples), y_true] -= 1
        # Normalize gradientcr
        self.dinputs = self.dinputs / samples


# Create dataset
X, y = spiral_data(samples=100, classes=2)

dense1 = Layer_Dense(2, 2)

activation1 = Activation_ReLU()

dense2 = Layer_Dense(2, 2)

# Create Softmax classifier's combined loss and activation
loss_activation = Activation_Softmax_Loss_CategoricalCrossentropy()

# Perform a forward pass of our training data through this layer
dense1.forward(X)

# Perform a forward pass through activation function
# takes the output of first dense layer here
activation1.forward(dense1.output)

# Perform a forward pass through second Dense layer
# takes outputs of activation function of first layer as inputs
dense2.forward(activation1.output)

# Perform a forward pass through the activation/loss function
# takes the output of second dense layer here and returns loss
loss = loss_activation.forward(dense2.output, y)

# Print loss value
print('loss:', loss)

# Calculate accuracy from output of activation2 and targets
# calculate values along first axis
predictions = np.argmax(loss_activation.output, axis=1)
if len(y.shape) == 2:
    y = np.argmax(y, axis=1)
accuracy = np.mean(predictions==y)

# Print accuracy
print('acc:', accuracy)

# Backward pass
loss_activation.backward(loss_activation.output, y)
dense2.backward(loss_activation.dinputs)
activation1.backward(dense2.dinputs)
dense1.backward(activation1.dinputs)
# Out:
# loss: 0.69314665
# acc: 0.525

# %%
from keras.models import Sequential
from keras.layers import Dense
import pandas as pd
from sklearn.model_selection import train_test_split

X1, y1 = spiral_data(samples=100, classes=2)
X1_train, X1_test, y1_train, y1_test = train_test_split(X1, y1, test_size=0.33, random_state=20) 
model = Sequential()
model.add(Dense(2, activation='relu', input_shape=(2,)))
model.add(Dense(2, activation='relu'))
model.compile(loss='binary_crossentropy', optimizer='sgd', metrics=['accuracy'])
model.fit(X1_train, y1_train, epochs=100, batch_size=1, verbose=1)
# Out:
# Epoch 1/100
# 134/134 [==============================] - 1s 2ms/step - loss: 1.8180 - accuracy: 0.5373
# Epoch 2/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.7723 - accuracy: 0.5075
# Epoch 3/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.7071 - accuracy: 0.5299
# Epoch 4/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.7014 - accuracy: 0.5597
# Epoch 5/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.7004 - accuracy: 0.5522
# Epoch 6/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.6949 - accuracy: 0.5373
# Epoch 7/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.6987 - accuracy: 0.5597
# Epoch 8/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.6970 - accuracy: 0.5672
# Epoch 9/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.6957 - accuracy: 0.5672
# Epoch 10/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.6961 - accuracy: 0.5746
# Epoch 11/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.6938 - accuracy: 0.5672
# Epoch 12/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.6943 - accuracy: 0.5522
# Epoch 13/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.6958 - accuracy: 0.5522
# Epoch 14/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.6913 - accuracy: 0.5597
# Epoch 15/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.6963 - accuracy: 0.5597
# Epoch 16/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.6958 - accuracy: 0.5448
# Epoch 17/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.6929 - accuracy: 0.5672
# Epoch 18/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.6954 - accuracy: 0.5522
# Epoch 19/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.6892 - accuracy: 0.5448
# Epoch 20/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.6945 - accuracy: 0.5373
# Epoch 21/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.6956 - accuracy: 0.5522
# Epoch 22/100
# 134/134 [==============================] - 0s 1ms/step - loss: 0.6925 - accuracy: 0.5448
# Epoch 23/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.6919 - accuracy: 0.5522
# Epoch 24/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.6944 - accuracy: 0.5522
# Epoch 25/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.6921 - accuracy: 0.5448
# Epoch 26/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.6919 - accuracy: 0.5522
# Epoch 27/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.6913 - accuracy: 0.5597
# Epoch 28/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.6902 - accuracy: 0.5597
# Epoch 29/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.6868 - accuracy: 0.5522
# Epoch 30/100
# 134/134 [==============================] - 0s 1ms/step - loss: 0.6919 - accuracy: 0.5522
# Epoch 31/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.6917 - accuracy: 0.5597
# Epoch 32/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.6882 - accuracy: 0.5597
# Epoch 33/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.6860 - accuracy: 0.5522
# Epoch 34/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.6913 - accuracy: 0.5597
# Epoch 35/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.6860 - accuracy: 0.5522
# Epoch 36/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.6904 - accuracy: 0.5522
# Epoch 37/100
# 134/134 [==============================] - 0s 1ms/step - loss: 0.6841 - accuracy: 0.5522
# Epoch 38/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.6821 - accuracy: 0.5597
# Epoch 39/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.6884 - accuracy: 0.5522
# Epoch 40/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.6891 - accuracy: 0.5448
# Epoch 41/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.6830 - accuracy: 0.5373
# Epoch 42/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.6905 - accuracy: 0.5522
# Epoch 43/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.6886 - accuracy: 0.5522
# Epoch 44/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.6878 - accuracy: 0.5448
# Epoch 45/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.6881 - accuracy: 0.5373
# Epoch 46/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.6882 - accuracy: 0.5373
# Epoch 47/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.6876 - accuracy: 0.5448
# Epoch 48/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.6868 - accuracy: 0.5448
# Epoch 49/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.6849 - accuracy: 0.5522
# Epoch 50/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.6883 - accuracy: 0.5299
# Epoch 51/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.6873 - accuracy: 0.5448
# Epoch 52/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.6838 - accuracy: 0.5448
# Epoch 53/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.6852 - accuracy: 0.5373
# Epoch 54/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.6786 - accuracy: 0.5448
# Epoch 55/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.6886 - accuracy: 0.5597
# Epoch 56/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.6809 - accuracy: 0.5522
# Epoch 57/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.6830 - accuracy: 0.5597
# Epoch 58/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.6855 - accuracy: 0.5522
# Epoch 59/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.6844 - accuracy: 0.5672
# Epoch 60/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.6843 - accuracy: 0.5672
# Epoch 61/100
# 134/134 [==============================] - 0s 1ms/step - loss: 0.6833 - accuracy: 0.5522
# Epoch 62/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.6829 - accuracy: 0.5672
# Epoch 63/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.6840 - accuracy: 0.5597
# Epoch 64/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.6674 - accuracy: 0.5597
# Epoch 65/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.6858 - accuracy: 0.5597
# Epoch 66/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.6797 - accuracy: 0.5672
# Epoch 67/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.6814 - accuracy: 0.5746
# Epoch 68/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.6827 - accuracy: 0.5522
# Epoch 69/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.6820 - accuracy: 0.5672
# Epoch 70/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.6822 - accuracy: 0.5597
# Epoch 71/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.6821 - accuracy: 0.5522
# Epoch 72/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.6809 - accuracy: 0.5672
# Epoch 73/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.6786 - accuracy: 0.5597
# Epoch 74/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.6777 - accuracy: 0.5597
# Epoch 75/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.6811 - accuracy: 0.5672
# Epoch 76/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.6795 - accuracy: 0.5597
# Epoch 77/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.6815 - accuracy: 0.5597
# Epoch 78/100
# 134/134 [==============================] - 0s 1ms/step - loss: 0.6802 - accuracy: 0.5672
# Epoch 79/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.6786 - accuracy: 0.5597
# Epoch 80/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.6813 - accuracy: 0.5672
# Epoch 81/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.6781 - accuracy: 0.5672
# Epoch 82/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.6755 - accuracy: 0.5896
# Epoch 83/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.6776 - accuracy: 0.5448
# Epoch 84/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.6803 - accuracy: 0.5672
# Epoch 85/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.6784 - accuracy: 0.5672
# Epoch 86/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.6778 - accuracy: 0.5672
# Epoch 87/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.6798 - accuracy: 0.5672
# Epoch 88/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.6771 - accuracy: 0.5597
# Epoch 89/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.6751 - accuracy: 0.5672
# Epoch 90/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.6788 - accuracy: 0.5821
# Epoch 91/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.6765 - accuracy: 0.5597
# Epoch 92/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.6771 - accuracy: 0.5672
# Epoch 93/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.6696 - accuracy: 0.5672
# Epoch 94/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.6735 - accuracy: 0.5896
# Epoch 95/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.6775 - accuracy: 0.5597
# Epoch 96/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.6769 - accuracy: 0.5746
# Epoch 97/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.6754 - accuracy: 0.5746
# Epoch 98/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.6762 - accuracy: 0.5597
# Epoch 99/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.6678 - accuracy: 0.5970
# Epoch 100/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.6753 - accuracy: 0.5821
